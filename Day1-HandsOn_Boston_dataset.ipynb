# %% [markdown]
# <a href="https://colab.research.google.com/github/ft10101/AI-ML/blob/main/HandsOn_Boston_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_boston

# %%
boston_dataset = load_boston()
boston_dataset
#storing boston data in boston_dataset
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
type(boston_dataset)
#datatype of boston_dataset
# Out:
# sklearn.utils.Bunch

# %%
boston_df = pd.DataFrame(boston_dataset.data, columns = boston_dataset.feature_names)
#converting  a dataset into dataframe including column names as already are present in the dataset called feature names

# %%
type(boston_df)
#data type of boston_df
# Out:
# pandas.core.frame.DataFrame

# %%
boston_df.head()
#first 5
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston_df.tail()
#last 5
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88

# %%
boston_df.shape
#dimensions of boston_df dataframe
# Out:
# (506, 13)

# %%
type(boston_df)
#data type of boston_df
# Out:
# pandas.core.frame.DataFrame

# %%
boston_df.info()
#information about boston_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
boston_df.isnull()
#which one is null and which is not
# Out:
#       CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501  False  False  False  False  False  False  False  False  False  False
# 502  False  False  False  False  False  False  False  False  False  False
# 503  False  False  False  False  False  False  False  False  False  False
# 504  False  False  False  False  False  False  False  False  False  False
# 505  False  False  False  False  False  False  False  False  False  False
#
#      PTRATIO      B  LSTAT
# 0      False  False  False
# ...

# %%
boston_df.isnull().sum()
#sum of all who are null
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
boston_dataset.feature_names
#checking for column names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
boston_df['ZN'] = boston_df.TAX
#changing values of ZN to the values of TAX

# %%
boston_df.to_csv('boston_CSV_file.csv')
#exporting the dataframe to CSV file

# %%
boston_df.to_excel('boston_EXCEL_file.xlsx')
#converting the dataframe to excel file

# %%
boston_df.drop(index=0,axis=0)
#remove a particular row
# Out:
#         CRIM     ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 1    0.02731  242.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729  242.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237  222.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905  222.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# 5    0.02985  222.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0  222.0
# ..       ...    ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263  273.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  273.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  273.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  273.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  273.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
boston_df.drop(columns='ZN', axis=1)
#removing a column
# Out:
#         CRIM  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0    0.00632   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0     15.3
# 1    0.02731   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0     17.8
# 2    0.02729   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0     17.8
# 3    0.03237   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0     18.7
# 4    0.06905   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0     18.7
# ..       ...    ...   ...    ...    ...   ...     ...  ...    ...      ...
# 501  0.06263  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0     21.0
# 502  0.04527  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0     21.0
# 503  0.06076  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0     21.0
# 504  0.10959  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0     21.0
# 505  0.04741  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0     21.0
#
#           B  LSTAT
# 0    396.90   4.98
# 1    396.90   9.14
# ...

# %%
boston_df.value_counts('CRIM')
#Counting values of a particular column
# Out:
# CRIM
# 14.33370    2
# 0.01501     2
# 1.05393     1
# 1.41385     1
# 1.38799     1
#            ..
# 0.11069     1
# 0.11027     1
# 0.10959     1
# 0.10793     1
# 88.97620    1
# Length: 504, dtype: int64

# %%
boston_df.count()
#count of every attribute
# Out:
# CRIM       506
# ZN         506
# INDUS      506
# CHAS       506
# NOX        506
# RM         506
# AGE        506
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      506
# dtype: int64

# %%
boston_df.mean()
#mean of every attribute
# Out:
# CRIM         3.613524
# ZN         408.237154
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# dtype: float64

# %%
boston_df.std()
#standard deviation
# Out:
# CRIM         8.601545
# ZN         168.537116
# INDUS        6.860353
# CHAS         0.253994
# NOX          0.115878
# RM           0.702617
# AGE         28.148861
# DIS          2.105710
# RAD          8.707259
# TAX        168.537116
# PTRATIO      2.164946
# B           91.294864
# LSTAT        7.141062
# dtype: float64

# %%
boston_df.min()
#minimum of every attribute
# Out:
# CRIM         0.00632
# ZN         187.00000
# INDUS        0.46000
# CHAS         0.00000
# NOX          0.38500
# RM           3.56100
# AGE          2.90000
# DIS          1.12960
# RAD          1.00000
# TAX        187.00000
# PTRATIO     12.60000
# B            0.32000
# LSTAT        1.73000
# dtype: float64

# %%
boston_df.max()
#maximum among every attribute
# Out:
# CRIM        88.9762
# ZN         711.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# dtype: float64

# %%
boston_df.describe()
#describe includes std(), min() and max()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   11.136779    0.069170    0.554695    6.284634
# std      8.601545  168.537116    6.860353    0.253994    0.115878    0.702617
# min      0.006320  187.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045  279.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510  330.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083  666.000000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  711.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
print(boston_df.iloc[:,0]) #every row ,first column
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64

# %%
print(boston_df.iloc[:,-1]) #every row ,last column
# Out:
# 0      4.98
# 1      9.14
# 2      4.03
# 3      2.94
# 4      5.33
#        ...
# 501    9.67
# 502    9.08
# 503    5.64
# 504    6.48
# 505    7.88
# Name: LSTAT, Length: 506, dtype: float64

# %%
print(boston_df.iloc[:,0]) #every row ,first column
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64
